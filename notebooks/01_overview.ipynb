# %% [markdown]
# # Diabetes Prediction Based on Clinical and Demographic Features
# ---

# %% [markdown]
# Kaggle description:
#
# The Diabetes prediction dataset is a collection of medical and demographic data from patients, along with their diabetes status (positive or negative). The data includes features such as age, gender, body mass index (BMI), hypertension, heart disease, smoking history, HbA1c level, and blood glucose level. This dataset can be used to build machine learning models to predict diabetes in patients based on their medical history and demographic information. This can be useful for healthcare professionals in identifying patients who may be at risk of developing diabetes and in developing personalized treatment plans. Additionally, the dataset can be used by researchers to explore the relationships between various medical and demographic factors and the likelihood of developing diabetes.

# %% [markdown]
# Source link: https://www.kaggle.com/datasets/iammustafatz/diabetes-prediction-dataset/data

# %% [markdown]
# ### Dataset Features Description
#
# | Feature | Description                                                                                                                                                                                                    | Data Type |
# |----------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-----------|
# | **gender** | Biological sex of the patient. Possible values include **Male**, **Female**, and **Other**.                                                                                                                    | Categorical |
# | **age** | Age of the patient in years.                                                                                                                                                                                   | Numerical (Continuous) |
# | **hypertension** | Indicates whether the patient has hypertension (high blood pressure). **0 = No**, **1 = Yes**.                                                                                                                 | Binary |
# | **heart_disease** | Indicates whether the patient has been diagnosed with heart disease. **0 = No**, **1 = Yes**.                                                                                                                  | Binary |
# | **smoking_history** | Smoking status of the patient. Possible categories include **never**, **former**, **current**, **not current**, **ever**, and **No Info**.                                                                     | Categorical |
# | **bmi** | Body Mass Index (BMI), calculated as weight (kg) divided by the square of height (m2). It is commonly used to assess whether a person has a healthy body weight.                                               | Numerical (Continuous) |
# | **HbA1c_level** | Glycated Hemoglobin (HbA1c) level expressed as a percentage. It reflects the patient's average blood glucose level over the previous 2–3 months and is a key indicator for diagnosing and monitoring diabetes. | Numerical (Continuous) |
# | **blood_glucose_level** | Current blood glucose concentration measured in **mg/dL**. Higher values may indicate impaired glucose regulation or diabetes.                                                                                 | Numerical (Continuous) |
# | **diabetes** | **Target variable.** Indicates whether the patient has diabetes. **0 = No Diabetes**, **1 = Diabetes**.                                                                                                        | Binary |

# %%
import pandas as pd

# %%
data = pd.read_csv('../data/raw/diabetes_prediction_dataset.csv')
data
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
# Checking the shape of the dataset
data.shape # -> shows 100k rows and 9 features
# Out:
# (100000, 9)

# %%
# Checking all column names. We can see if is need to process the features to make them consistent
data.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
# Checking how many are the features of the dataset
len(data.columns)
# Out:
# 9

# %%
# Checking the type of the features
data.dtypes
# Out:
# gender                  object
# age                    float64
# hypertension             int64
# heart_disease            int64
# smoking_history         object
# bmi                    float64
# HbA1c_level            float64
# blood_glucose_level      int64
# diabetes                 int64
# dtype: object

# %%
# Checking fo null values in the features
data.isna().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
# Checking the target distribution. 8.5% positive diagnosis with diabetes.
data['diabetes'].value_counts()
# Out:
# diabetes
# 0    91500
# 1     8500
# Name: count, dtype: int64

# %%
# Checking the distribution of the genders. Around 60/40 female and male
data['gender'].value_counts()
# Out:
# gender
# Female    58552
# Male      41430
# Other        18
# Name: count, dtype: int64

# %%
# Checking the distribution of smoking history. In the next notebook (02_eda.ipynb), the analysis will be deeper about the features.
data['smoking_history'].value_counts()
# Out:
# smoking_history
# No Info        35816
# never          35095
# former          9352
# current         9286
# not current     6447
# ever            4004
# Name: count, dtype: int64

# %%
# Those patients (1) are with high blood pressure. But what does it mean high blood pressure - maybe 130/90, 140/90, 145/100 ... etc. I think, it's depend on the person
data['hypertension'].value_counts()
# Out:
# hypertension
# 0    92515
# 1     7485
# Name: count, dtype: int64

# %%
# From this point onward, if we need to access the original data, we will use
# "working_dataset.csv", which is a copy of the original dataset.
# This ensures that the original data remains unchanged throughout the project
# and allows us to safely perform preprocessing and feature engineering.
dataset_org = data.to_csv('../data/processed/working_dataset.csv', index=False)
